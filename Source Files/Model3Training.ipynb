# %%
import numpy as np
import librosa
import os
import glob
import gc
import tensorflow as tf
from tensorflow import keras
import json

from google.colab import drive
drive.mount('/content/gdrive')
driveLoc='/content/gdrive/My Drive/MLSP Project/'
# Out:
# Mounted at /content/gdrive

# %%
data_loc = driveLoc + 'CQCC/'

training_bonafide_folders = 6
training_spoof_folders = 46

validation_bonafide_folders = 6
validation_spoof_folders = 45

samples_per_folder = 500

# %% [markdown]
# ### Training Model

# %%
training_samples = 4000
validation_samples = 400
ratio_of_bonafide_samples = 0.5
data_iterations = 10
epochs_per_iteration = 10
size_of_batch = 128
alpha = 0.001 #learning_rate

# %%
training_data_mean = np.loadtxt(data_loc+'train_mean_CQCC.txt', delimiter=',')
training_data_stddev = np.loadtxt(data_loc+'train_stddev_CQCC.txt', delimiter=',')
(dim1, dim2) = np.shape(training_data_mean)
print(dim1, dim2)

def GenerateFeatures(filename): #Generates Normalized Features
    features = np.loadtxt(filename, delimiter=',')
    return (features-training_data_mean)/training_data_stddev
# Out:
# 90 469

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Creating Bonafide Training Data

# %%
with open(data_loc + "bonafide_train_set_files.txt", "r") as fp:
    bonafide_train_files = json.load(fp)

bonafide_train_data = np.zeros((len(bonafide_train_files), dim1, dim2), dtype = np.float32)

for i in range(len(bonafide_train_files)):
    bonafide_train_data[i,:,:] = GenerateFeatures(bonafide_train_files[i])
    if (i+1)%500 == 0:
        print('Generated {} bonafide features...'.format(i+1))

del bonafide_train_files
gc.collect()
# Out:
# Generated 500 bonafide features...
# Generated 1000 bonafide features...
# Generated 1500 bonafide features...
# Generated 2000 bonafide features...
# Generated 2500 bonafide features...
# Generated 3000 bonafide features...
# Generated 3500 bonafide features...
# Generated 4000 bonafide features...
# 152

# %%
with open(data_loc + "spoof_train_set_files.txt", "r") as fp:
    spoof_train_files = json.load(fp)

with open(data_loc + "bonafide_valid_set_files.txt", "r") as fp:
    bonafide_valid_files = json.load(fp)

with open(data_loc + "spoof_valid_set_files.txt", "r") as fp:
    spoof_valid_files = json.load(fp)

# %% [markdown]
# ### Model Creation and Loading

# %%
print(keras.backend.image_data_format())
img_shape = (dim1, dim2, 1)
# Out:
# channels_last

# %%
def CreateModel(dropout_rate, kernel_no):
    model = keras.models.Sequential()
    # initializer = tf.keras.initializers.GlorotUniform()
    opt = keras.optimizers.Adam(learning_rate=alpha)

    # input-processing block
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), input_shape=img_shape, 
                                activation='relu', strides = 2, padding = 'same'))
    model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2)) # remove thisssssss

    # convolutional-block (1)
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(4, 4), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    # # convolutional-block (2)
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(4, 4), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    # convolutional-block (3)
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(2, 2), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    # # convolutional-block (4)
    # model.add(keras.layers.Conv2D(kernel_no, kernel_size=(4, 4), activation='relu'))
    # model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    # model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    model.add( keras.layers.Flatten() )

    # classification-block
    model.add(keras.layers.Dropout(dropout_rate))
    model.add( keras.layers.Dense(64))
    model.add( keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dropout(dropout_rate))
    model.add( keras.layers.Dense(32))

    # output layer
    model.add( keras.layers.Dense(2, activation='softmax') )

    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model

# %%
model1 = CreateModel(0.1, 4)
model2 = CreateModel(0.15, 4)
model3 = CreateModel(0.2, 4)
model4 = CreateModel(0.25, 4)
model5 = CreateModel(0.3, 4)
model6 = CreateModel(0.1, 8)
model7 = CreateModel(0.15, 8)
model8 = CreateModel(0.2, 8)
model9 = CreateModel(0.25, 8)
model10 = CreateModel(0.3, 8)

# %%
model1.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_78 (Conv2D)           (None, 45, 235, 4)        40
# _________________________________________________________________
# batch_normalization_87 (Batc (None, 45, 235, 4)        16
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 42, 232, 4)        260
# _________________________________________________________________
# batch_normalization_88 (Batc (None, 42, 232, 4)        16
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 40, 230, 4)        148
# _________________________________________________________________
# batch_normalization_89 (Batc (None, 40, 230, 4)        16
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 20, 115, 4)        0
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 17, 112, 4)        260
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 17, 112, 4)        16
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 15, 110, 4)        148
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 15, 110, 4)        16
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 7, 55, 4)          0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 6, 54, 4)          68
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 6, 54, 4)          16
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 4, 52, 4)          148
# _________________________________________________________________
# batch_normalization_93 (Batc (None, 4, 52, 4)          16
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 2, 26, 4)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 208)               0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 208)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 64)                13376
# _________________________________________________________________
# dense_41 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_94 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 21,122
# Trainable params: 20,938
# Non-trainable params: 184
# _________________________________________________________________

# %%
model6.summary()

# %%
print(keras.backend.eval(model1.optimizer.lr))
print(keras.backend.eval(model2.optimizer.lr))
print(keras.backend.eval(model3.optimizer.lr))
print(keras.backend.eval(model4.optimizer.lr))
print(keras.backend.eval(model5.optimizer.lr))
print(keras.backend.eval(model6.optimizer.lr))
print(keras.backend.eval(model7.optimizer.lr))
print(keras.backend.eval(model8.optimizer.lr))
print(keras.backend.eval(model9.optimizer.lr))
print(keras.backend.eval(model10.optimizer.lr))
# Out:
# 0.001
# 0.001
# 0.001
# 0.001
# 0.001
# 0.001
# 0.001
# 0.001
# 0.001
# 0.001

# %%
model1 = keras.models.load_model(driveLoc+'Models/21_june01/3')
model2 = keras.models.load_model(driveLoc+'Models/21_june02/3')
model3 = keras.models.load_model(driveLoc+'Models/21_june03/3')
model4 = keras.models.load_model(driveLoc+'Models/21_june04/3')
model5 = keras.models.load_model(driveLoc+'Models/21_june05/3')
model6 = keras.models.load_model(driveLoc+'Models/21_june06/3')
model7 = keras.models.load_model(driveLoc+'Models/21_june07/3')
model8 = keras.models.load_model(driveLoc+'Models/21_june08/3')
model9 = keras.models.load_model(driveLoc+'Models/21_june09/3')
model10 = keras.models.load_model(driveLoc+'Models/21_june10/3')

# %% [markdown]
# ### Training

# %%
training_data = np.zeros((training_samples, dim1, dim2, 1), dtype = np.float32)
validation_data = np.zeros((validation_samples, dim1, dim2, 1), dtype = np.float32)

training_fill = training_samples//2
validation_fill = validation_samples//2
len_spoof_train_file = len(spoof_train_files)
len_bonafide_valid_file = len(bonafide_valid_files)
len_spoof_valid_file = len(spoof_valid_files)
bon_train_samples = np.shape(bonafide_train_data)[0]
training_bonafide_number = int(ratio_of_bonafide_samples*training_samples)
validation_bonafide_number = int(ratio_of_bonafide_samples*validation_samples)

bonafide_label = 0

j = 0
k = 0

count = 30
i = 20000
print('Generating Data for training process no. {}...'.format(count+1))
while  i <  data_iterations*len_spoof_train_file:
    i+=1
    training_data[i%training_fill,:,:,0] = GenerateFeatures(spoof_train_files[i%len_spoof_train_file])
    if (i+1)%training_fill == 0:
        print("Last data point was generated with index {}".format(i))
        for p in range(training_fill):
            training_data[p+training_fill,:,:,0] = bonafide_train_data[(j+p)%bon_train_samples, :, :]
        j += training_fill

        training_labels = np.append((1-bonafide_label)*np.ones(training_samples-training_bonafide_number), 
                                        bonafide_label*np.ones(training_bonafide_number))
                                        
        validation_labels = np.append(bonafide_label*np.ones(validation_bonafide_number), 
                                        (1-bonafide_label)*np.ones(validation_samples-validation_bonafide_number))
        for p in range(validation_fill):
            validation_data[p,:,:,0] = GenerateFeatures(bonafide_valid_files[k%len_bonafide_valid_file])
            validation_data[p+validation_fill,:,:,0] = GenerateFeatures(spoof_valid_files[k%len_spoof_valid_file])
            k += 1
        
        print("Training Model 01...")
        model1.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 02...")
        model2.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 03...")
        model3.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 04...")
        model4.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 05...")
        model5.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 06...")
        model6.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 07...")
        model7.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 08...")
        model8.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 09...")
        model9.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 10...")
        model10.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        
        if (count+1)%10 == 0:
            model1.save(driveLoc+'Models/21_june01/'+str((count+1)//10))
            model2.save(driveLoc+'Models/21_june02/'+str((count+1)//10))
            model3.save(driveLoc+'Models/21_june03/'+str((count+1)//10))
            model4.save(driveLoc+'Models/21_june04/'+str((count+1)//10))
            model5.save(driveLoc+'Models/21_june05/'+str((count+1)//10))
            model6.save(driveLoc+'Models/21_june06/'+str((count+1)//10))
            model7.save(driveLoc+'Models/21_june07/'+str((count+1)//10))
            model8.save(driveLoc+'Models/21_june08/'+str((count+1)//10))
            model9.save(driveLoc+'Models/21_june09/'+str((count+1)//10))
            model10.save(driveLoc+'Models/21_june10/'+str((count+1)//10))
        if count > 20 and (count+1)%20 == 0:
            alpha = keras.backend.eval(model1.optimizer.lr)
            print('Updating step size to {}...'.format(alpha/2))
            keras.backend.set_value(model1.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model2.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model3.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model4.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model5.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model6.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model7.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model8.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model9.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model10.optimizer.learning_rate, alpha/2)
        if(count+1 == 40):
            epochs_per_iteration = 5
        count+=1    
        print('Generating Data for training process no. {}...'.format(count+1))
        
        del training_labels
        del validation_labels
        gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.1043e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.0239e-06 - accuracy: 1.0000 - val_loss: 2.0338e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 9.3964e-05 - accuracy: 1.0000 - val_loss: 1.4364e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.4795e-06 - accuracy: 1.0000 - val_loss: 1.9210e-04 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 45ms/step - loss: 9.8435e-05 - accuracy: 1.0000 - val_loss: 2.6539e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 9.9179e-06 - accuracy: 1.0000 - val_loss: 5.8892e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.0218e-05 - accuracy: 1.0000 - val_loss: 7.8501e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.7980e-06 - accuracy: 1.0000 - val_loss: 1.8579e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.8044e-05 - accuracy: 1.0000 - val_loss: 6.1126e-06 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june01/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june02/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june03/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june04/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june05/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june06/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june07/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june08/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june09/9/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/21_june10/9/assets
# Generating Data for training process no. 91...
# Last data point was generated with index 141999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 4.4973e-04 - accuracy: 0.9998 - val_loss: 1.1508e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.7659e-04 - accuracy: 1.0000 - val_loss: 1.7313e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.4669e-04 - accuracy: 1.0000 - val_loss: 1.5002e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 5.9172e-05 - accuracy: 1.0000 - val_loss: 1.2942e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.7797e-04 - accuracy: 0.9998 - val_loss: 1.6833e-04 - val_accuracy: 1.0000
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 1.0558e-04 - accuracy: 1.0000 - val_loss: 3.3525e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.0375e-04 - accuracy: 0.9998 - val_loss: 3.5567e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.6303e-04 - accuracy: 1.0000 - val_loss: 1.8344e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.9604e-04 - accuracy: 0.9998 - val_loss: 1.2903e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 4.5914e-04 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.5500e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.7364e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.0211e-04 - accuracy: 0.9998 - val_loss: 0.0131 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0066 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 6.5958e-04 - accuracy: 0.9998 - val_loss: 0.0069 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 4.4625e-04 - accuracy: 1.0000 - val_loss: 2.8414e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 2.8779e-04 - accuracy: 1.0000 - val_loss: 1.8917e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.2684e-04 - accuracy: 0.9998 - val_loss: 1.7686e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 1.0530e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 1.7751e-04 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 9.7218e-04 - accuracy: 0.9998 - val_loss: 0.0169 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0240 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0344 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 9.9071e-04 - accuracy: 0.9995 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0078 - val_accuracy: 0.9950
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 4.8601e-05 - accuracy: 1.0000 - val_loss: 1.9526e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 44ms/step - loss: 4.8126e-04 - accuracy: 0.9998 - val_loss: 6.6107e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 9.9645e-06 - accuracy: 1.0000 - val_loss: 2.9629e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.9176e-05 - accuracy: 1.0000 - val_loss: 2.0527e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.3173e-06 - accuracy: 1.0000 - val_loss: 3.1185e-05 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.0863e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.5870e-04 - accuracy: 0.9998 - val_loss: 0.0055 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 8.1576e-05 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.3098e-05 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 8.0985e-06 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9975
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 2.3145e-04 - accuracy: 1.0000 - val_loss: 2.0891e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 9.7452e-06 - accuracy: 1.0000 - val_loss: 1.0788e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.9366e-05 - accuracy: 1.0000 - val_loss: 1.1951e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.6829e-06 - accuracy: 1.0000 - val_loss: 1.3292e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.7023e-05 - accuracy: 1.0000 - val_loss: 1.6451e-07 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 45ms/step - loss: 1.0152e-04 - accuracy: 1.0000 - val_loss: 2.1724e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 9.9675e-05 - accuracy: 1.0000 - val_loss: 2.8828e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.3345e-05 - accuracy: 1.0000 - val_loss: 4.4779e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 8.6622e-05 - accuracy: 1.0000 - val_loss: 5.3362e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.1800e-06 - accuracy: 1.0000 - val_loss: 5.9276e-06 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 8.6894e-04 - accuracy: 0.9998 - val_loss: 1.1507e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.9450e-05 - accuracy: 1.0000 - val_loss: 9.4996e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.1412e-05 - accuracy: 1.0000 - val_loss: 1.6825e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 44ms/step - loss: 2.7128e-05 - accuracy: 1.0000 - val_loss: 6.9905e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.5757e-05 - accuracy: 1.0000 - val_loss: 4.1844e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 92...
# Last data point was generated with index 143999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 4.6847e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 7.2516e-04 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 6.4082e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.5373e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.7173e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.9432e-04 - accuracy: 0.9998 - val_loss: 0.0334 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 4.8388e-04 - accuracy: 0.9998 - val_loss: 0.0161 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 8.4622e-05 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.9984e-04 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9950
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 2.9571e-04 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 7.2218e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.0666e-04 - accuracy: 1.0000 - val_loss: 5.1153e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 5.1953e-04 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.7178e-04 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 8.3648e-04 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 5.9010e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 8.9507e-04 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 7.0039e-04 - accuracy: 0.9998 - val_loss: 0.0058 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.7079e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9975
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0063 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0031 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 5.9237e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 8.4262e-04 - val_accuracy: 1.0000
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 5.4037e-06 - accuracy: 1.0000 - val_loss: 5.4864e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 44ms/step - loss: 7.5425e-06 - accuracy: 1.0000 - val_loss: 5.9490e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.4060e-05 - accuracy: 1.0000 - val_loss: 6.4356e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.7484e-05 - accuracy: 1.0000 - val_loss: 1.0038e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.8963e-06 - accuracy: 1.0000 - val_loss: 9.4242e-05 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 45ms/step - loss: 1.1293e-04 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0532e-05 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 0.9925
# Epoch 3/5
# 32/32 [==============================] - 1s 44ms/step - loss: 4.4908e-05 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.4453e-05 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.9821e-05 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9950
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 3.4201e-06 - accuracy: 1.0000 - val_loss: 3.8364e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.1626e-05 - accuracy: 1.0000 - val_loss: 6.3331e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 8.2917e-06 - accuracy: 1.0000 - val_loss: 5.6349e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.2016e-05 - accuracy: 1.0000 - val_loss: 8.0620e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.0526e-06 - accuracy: 1.0000 - val_loss: 7.0887e-06 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.0616e-04 - accuracy: 0.9998 - val_loss: 9.1400e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.0868e-05 - accuracy: 1.0000 - val_loss: 8.5636e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 1.7788e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.9309e-05 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9900
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.3145e-06 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9975
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 45ms/step - loss: 4.1873e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.3528e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.3066e-06 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 44ms/step - loss: 2.0371e-05 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.1159e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Generating Data for training process no. 93...
# Last data point was generated with index 145999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 7.0161e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.9379e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 7.8718e-04 - accuracy: 0.9995 - val_loss: 0.0020 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 6.4949e-05 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0072 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 7.9851e-04 - accuracy: 0.9998 - val_loss: 8.5296e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 4.8551e-04 - accuracy: 0.9998 - val_loss: 9.1094e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 9.6140e-05 - accuracy: 1.0000 - val_loss: 8.5160e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.7467e-04 - accuracy: 1.0000 - val_loss: 1.4877e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 1.7780e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0022 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0228 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0253 - val_accuracy: 0.9925
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0480 - val_accuracy: 0.9900
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 7.0783e-04 - accuracy: 0.9995 - val_loss: 0.0024 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 7.0329e-05 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 5.4706e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.8558e-04 - accuracy: 1.0000 - val_loss: 1.9695e-04 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0084 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.4910e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0071 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 0.0038 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0081 - val_accuracy: 0.9975
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 2.2134e-05 - accuracy: 1.0000 - val_loss: 9.2776e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.5108e-04 - accuracy: 1.0000 - val_loss: 1.5547e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 44ms/step - loss: 3.8936e-04 - accuracy: 0.9998 - val_loss: 2.5072e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.2728e-05 - accuracy: 1.0000 - val_loss: 2.7233e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 7.3363e-06 - accuracy: 1.0000 - val_loss: 2.0010e-04 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 9.2953e-05 - accuracy: 1.0000 - val_loss: 2.0299e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.4030e-05 - accuracy: 1.0000 - val_loss: 1.4957e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.2968e-04 - accuracy: 0.9998 - val_loss: 7.2283e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.2886e-04 - accuracy: 1.0000 - val_loss: 4.9240e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 9.2057e-05 - accuracy: 1.0000 - val_loss: 7.5910e-06 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.0367e-05 - accuracy: 1.0000 - val_loss: 1.7613e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.0950e-06 - accuracy: 1.0000 - val_loss: 1.6600e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 9.8069e-07 - accuracy: 1.0000 - val_loss: 1.6123e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.3141e-06 - accuracy: 1.0000 - val_loss: 1.4037e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.2304e-06 - accuracy: 1.0000 - val_loss: 1.4484e-07 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 45ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 4.3568e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.8709e-05 - accuracy: 1.0000 - val_loss: 5.4197e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.4534e-05 - accuracy: 1.0000 - val_loss: 6.7924e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.1947e-05 - accuracy: 1.0000 - val_loss: 8.0587e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.3453e-06 - accuracy: 1.0000 - val_loss: 1.1018e-04 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.1791e-04 - accuracy: 1.0000 - val_loss: 4.4318e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 8.4783e-05 - accuracy: 1.0000 - val_loss: 9.0506e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0756e-04 - accuracy: 1.0000 - val_loss: 8.6035e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 9.9574e-06 - accuracy: 1.0000 - val_loss: 2.3557e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.2550e-05 - accuracy: 1.0000 - val_loss: 3.2368e-05 - val_accuracy: 1.0000
# Generating Data for training process no. 94...
# Last data point was generated with index 147999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 7.7024e-04 - accuracy: 0.9995 - val_loss: 6.6350e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.4120e-04 - accuracy: 1.0000 - val_loss: 5.1700e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 7.8576e-05 - accuracy: 1.0000 - val_loss: 5.4625e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.1651e-04 - accuracy: 0.9998 - val_loss: 8.1095e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 6.4370e-04 - accuracy: 0.9998 - val_loss: 0.0163 - val_accuracy: 0.9900
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 39ms/step - loss: 4.5989e-04 - accuracy: 0.9998 - val_loss: 7.7741e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.4949e-04 - accuracy: 1.0000 - val_loss: 1.6800e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.2754e-05 - accuracy: 1.0000 - val_loss: 5.2987e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.8574e-05 - accuracy: 1.0000 - val_loss: 6.3089e-07 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 40ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0250 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0232 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 6.4229e-04 - accuracy: 0.9998 - val_loss: 0.0205 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 7.6387e-05 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 4.9763e-04 - accuracy: 0.9998 - val_loss: 0.0185 - val_accuracy: 0.9950
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 1.2880e-04 - accuracy: 1.0000 - val_loss: 2.3732e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 4.7110e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 2.0636e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.7691e-04 - accuracy: 0.9998 - val_loss: 6.2741e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 1.1451e-04 - accuracy: 1.0000 - val_loss: 9.8351e-05 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 0.0015 - accuracy: 0.9990 - val_loss: 0.0052 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0066 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 6.5500e-04 - accuracy: 0.9998 - val_loss: 0.0126 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0178 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0355 - val_accuracy: 0.9900
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.0350e-04 - accuracy: 1.0000 - val_loss: 6.5512e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 44ms/step - loss: 4.3669e-06 - accuracy: 1.0000 - val_loss: 2.7114e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.0442e-06 - accuracy: 1.0000 - val_loss: 2.2952e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.5468e-04 - accuracy: 0.9998 - val_loss: 8.0690e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 6.9595e-06 - accuracy: 1.0000 - val_loss: 8.7807e-06 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.3231e-05 - accuracy: 1.0000 - val_loss: 7.4153e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 7.7213e-06 - accuracy: 1.0000 - val_loss: 1.5545e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.9895e-04 - accuracy: 0.9998 - val_loss: 1.0423e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.3419e-04 - accuracy: 0.9998 - val_loss: 2.8680e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.7693e-06 - accuracy: 1.0000 - val_loss: 9.9230e-05 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.0192e-05 - accuracy: 1.0000 - val_loss: 4.2157e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.2165e-05 - accuracy: 1.0000 - val_loss: 4.7354e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 44ms/step - loss: 3.1607e-06 - accuracy: 1.0000 - val_loss: 4.0023e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.7983e-05 - accuracy: 1.0000 - val_loss: 6.2075e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 6.3531e-05 - accuracy: 1.0000 - val_loss: 4.4611e-07 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 1.3146e-04 - accuracy: 1.0000 - val_loss: 9.3452e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.5822e-05 - accuracy: 1.0000 - val_loss: 8.0133e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.1557e-04 - accuracy: 1.0000 - val_loss: 2.0270e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.6742e-05 - accuracy: 1.0000 - val_loss: 2.0243e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.1410e-05 - accuracy: 1.0000 - val_loss: 1.8358e-06 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.4850e-04 - accuracy: 0.9998 - val_loss: 1.5401e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.3791e-04 - accuracy: 0.9998 - val_loss: 5.1631e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.0474e-05 - accuracy: 1.0000 - val_loss: 3.3431e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.0482e-05 - accuracy: 1.0000 - val_loss: 2.1723e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.5346e-04 - accuracy: 0.9998 - val_loss: 2.8720e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 95...
# Last data point was generated with index 149999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0038 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0062 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 36ms/step - loss: 4.7474e-04 - accuracy: 0.9998 - val_loss: 0.0063 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.5704e-04 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.0047e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 2.5846e-04 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0176 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.6978e-04 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0078 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0027 - val_accuracy: 0.9975
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 4.9479e-04 - accuracy: 1.0000 - val_loss: 3.2501e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 38ms/step - loss: 4.2154e-04 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 2.8074e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 1.5991e-04 - accuracy: 1.0000 - val_loss: 2.6209e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.5719e-04 - accuracy: 1.0000 - val_loss: 2.0238e-04 - val_accuracy: 1.0000
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 39ms/step - loss: 3.4808e-04 - accuracy: 1.0000 - val_loss: 3.8663e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 6.6500e-04 - accuracy: 0.9998 - val_loss: 2.7329e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.7824e-04 - accuracy: 1.0000 - val_loss: 2.2586e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 2.4173e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.1536e-04 - accuracy: 0.9998 - val_loss: 2.4164e-04 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0027 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0019 - val_accuracy: 1.0000
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.4456e-04 - accuracy: 0.9998 - val_loss: 2.8782e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.2619e-04 - accuracy: 0.9998 - val_loss: 1.3262e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.1336e-05 - accuracy: 1.0000 - val_loss: 1.3174e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 1.3329e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.5266e-04 - accuracy: 0.9998 - val_loss: 0.0240 - val_accuracy: 0.9950
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 4.7624e-05 - accuracy: 1.0000 - val_loss: 1.0237e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 6.5032e-05 - accuracy: 1.0000 - val_loss: 8.9375e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.1960e-04 - accuracy: 1.0000 - val_loss: 6.5710e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.2387e-04 - accuracy: 0.9998 - val_loss: 1.3640e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.1499e-05 - accuracy: 1.0000 - val_loss: 5.4830e-04 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 4.3629e-06 - accuracy: 1.0000 - val_loss: 1.0543e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.3887e-05 - accuracy: 1.0000 - val_loss: 1.3317e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.1288e-06 - accuracy: 1.0000 - val_loss: 1.6140e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 6.8199e-05 - accuracy: 1.0000 - val_loss: 5.8643e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.3823e-06 - accuracy: 1.0000 - val_loss: 5.2917e-06 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 8.5835e-06 - accuracy: 1.0000 - val_loss: 6.7811e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 8.2159e-06 - accuracy: 1.0000 - val_loss: 7.3192e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.5191e-05 - accuracy: 1.0000 - val_loss: 6.7629e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.3981e-05 - accuracy: 1.0000 - val_loss: 5.8452e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.2264e-05 - accuracy: 1.0000 - val_loss: 5.2080e-04 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 44ms/step - loss: 3.7490e-04 - accuracy: 0.9998 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 6.7638e-06 - accuracy: 1.0000 - val_loss: 2.6370e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 41ms/step - loss: 2.0496e-04 - accuracy: 0.9998 - val_loss: 2.6798e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 41ms/step - loss: 2.3208e-04 - accuracy: 0.9998 - val_loss: 8.3798e-07 - val_accuracy: 1.0000
# Generating Data for training process no. 96...
# Last data point was generated with index 151999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 8.7195e-04 - accuracy: 0.9995 - val_loss: 3.9488e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 3.0573e-04 - accuracy: 1.0000 - val_loss: 7.8579e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 36ms/step - loss: 3.9399e-04 - accuracy: 1.0000 - val_loss: 7.8837e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 2.9885e-04 - accuracy: 1.0000 - val_loss: 4.2913e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 1.8080e-04 - accuracy: 1.0000 - val_loss: 2.8845e-05 - val_accuracy: 1.0000
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 8.0146e-04 - accuracy: 0.9995 - val_loss: 7.9313e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 1.6801e-04 - accuracy: 1.0000 - val_loss: 1.1920e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.6831e-05 - accuracy: 1.0000 - val_loss: 1.5718e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 1.5092e-04 - accuracy: 1.0000 - val_loss: 1.6447e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 5.3362e-04 - accuracy: 0.9998 - val_loss: 2.2100e-05 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.7879e-04 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 9.7269e-04 - accuracy: 0.9995 - val_loss: 0.0242 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 8.3233e-05 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0039 - accuracy: 0.9987 - val_loss: 0.0093 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 5.8629e-04 - accuracy: 0.9998 - val_loss: 0.0033 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 8.2949e-04 - accuracy: 0.9995 - val_loss: 0.0022 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 36ms/step - loss: 3.8407e-04 - accuracy: 1.0000 - val_loss: 6.4156e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 5.9702e-04 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0080 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.5470e-04 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0181 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 3.5962e-04 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 0.9950
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.0593e-06 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 6.4039e-05 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 7.9531e-06 - accuracy: 1.0000 - val_loss: 8.4886e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 41ms/step - loss: 3.9464e-06 - accuracy: 1.0000 - val_loss: 4.8931e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 41ms/step - loss: 9.6446e-06 - accuracy: 1.0000 - val_loss: 3.6521e-04 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.0101e-06 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 41ms/step - loss: 2.6281e-06 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 41ms/step - loss: 5.5088e-04 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 6.8403e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.6025e-06 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 0.9975
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 42ms/step - loss: 8.5331e-06 - accuracy: 1.0000 - val_loss: 2.7179e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 9.9640e-06 - accuracy: 1.0000 - val_loss: 2.0772e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 41ms/step - loss: 2.3037e-06 - accuracy: 1.0000 - val_loss: 1.6093e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.6516e-05 - accuracy: 1.0000 - val_loss: 1.9014e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 41ms/step - loss: 1.5042e-05 - accuracy: 1.0000 - val_loss: 2.0385e-07 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.5708e-04 - accuracy: 1.0000 - val_loss: 4.6390e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 6.7646e-06 - accuracy: 1.0000 - val_loss: 1.3175e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 41ms/step - loss: 1.1697e-04 - accuracy: 1.0000 - val_loss: 4.0742e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.5246e-05 - accuracy: 1.0000 - val_loss: 3.2481e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 41ms/step - loss: 8.5240e-06 - accuracy: 1.0000 - val_loss: 3.1105e-06 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.1809e-06 - accuracy: 1.0000 - val_loss: 8.2737e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0102e-05 - accuracy: 1.0000 - val_loss: 4.6377e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 41ms/step - loss: 4.6914e-05 - accuracy: 1.0000 - val_loss: 3.7688e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 41ms/step - loss: 8.7186e-05 - accuracy: 1.0000 - val_loss: 6.7560e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 40ms/step - loss: 2.1012e-05 - accuracy: 1.0000 - val_loss: 7.7607e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 97...
# ...
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.3200e-05 - accuracy: 1.0000 - val_loss: 1.0564e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.7879e-06 - accuracy: 1.0000 - val_loss: 1.0771e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.1153e-05 - accuracy: 1.0000 - val_loss: 1.0095e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.7390e-05 - accuracy: 1.0000 - val_loss: 7.8325e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 133...
# Last data point was generated with index 225999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 2.9207e-04 - accuracy: 0.9998 - val_loss: 0.0064 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 1.1426e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.6769e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 1.1529e-04 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 2.2634e-04 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 7.2659e-05 - accuracy: 1.0000 - val_loss: 7.9089e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 8.9583e-04 - accuracy: 0.9992 - val_loss: 7.0685e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 36ms/step - loss: 3.9223e-04 - accuracy: 0.9998 - val_loss: 6.6204e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 36ms/step - loss: 6.2213e-05 - accuracy: 1.0000 - val_loss: 7.0648e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 2.4503e-04 - accuracy: 1.0000 - val_loss: 7.0717e-05 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.0733e-04 - accuracy: 1.0000 - val_loss: 4.8584e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.2686e-04 - accuracy: 0.9998 - val_loss: 3.6492e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.2775e-04 - accuracy: 1.0000 - val_loss: 4.7390e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.5445e-04 - accuracy: 1.0000 - val_loss: 2.2556e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 9.9227e-04 - accuracy: 0.9995 - val_loss: 1.2513e-04 - val_accuracy: 1.0000
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 6.5323e-04 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 36ms/step - loss: 1.3605e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 36ms/step - loss: 2.0346e-04 - accuracy: 1.0000 - val_loss: 8.5799e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.4690e-04 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 3.4553e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.0738e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 8.0918e-04 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0028 - val_accuracy: 0.9975
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 1.8024e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 6.0132e-06 - accuracy: 1.0000 - val_loss: 3.8635e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 9.6848e-06 - accuracy: 1.0000 - val_loss: 2.3441e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.0270e-06 - accuracy: 1.0000 - val_loss: 1.6139e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.5896e-04 - accuracy: 0.9998 - val_loss: 1.3955e-06 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 9.1685e-06 - accuracy: 1.0000 - val_loss: 8.5467e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0676e-04 - accuracy: 1.0000 - val_loss: 1.9819e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.6379e-05 - accuracy: 1.0000 - val_loss: 1.4873e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 9.3249e-06 - accuracy: 1.0000 - val_loss: 1.1205e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.7784e-04 - accuracy: 0.9998 - val_loss: 5.8079e-07 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.6351e-06 - accuracy: 1.0000 - val_loss: 6.7353e-08 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.9713e-06 - accuracy: 1.0000 - val_loss: 7.5102e-08 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 41ms/step - loss: 1.0975e-05 - accuracy: 1.0000 - val_loss: 7.7188e-08 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.1553e-05 - accuracy: 1.0000 - val_loss: 8.1062e-08 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 41ms/step - loss: 3.0961e-06 - accuracy: 1.0000 - val_loss: 7.9274e-08 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.7593e-06 - accuracy: 1.0000 - val_loss: 1.3900e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.8619e-06 - accuracy: 1.0000 - val_loss: 1.2728e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 8.0345e-06 - accuracy: 1.0000 - val_loss: 1.1958e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.3518e-06 - accuracy: 1.0000 - val_loss: 1.1385e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.0581e-06 - accuracy: 1.0000 - val_loss: 1.1459e-05 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.4494e-06 - accuracy: 1.0000 - val_loss: 2.2036e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.4983e-05 - accuracy: 1.0000 - val_loss: 1.6814e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.2841e-05 - accuracy: 1.0000 - val_loss: 1.8545e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.4889e-04 - accuracy: 1.0000 - val_loss: 1.5077e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 3.9645e-05 - accuracy: 1.0000 - val_loss: 1.2780e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 134...
# Last data point was generated with index 227999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 5.8382e-05 - accuracy: 1.0000 - val_loss: 3.7944e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.0821e-04 - accuracy: 0.9998 - val_loss: 5.2784e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.8398e-05 - accuracy: 1.0000 - val_loss: 5.7834e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 4.2302e-04 - accuracy: 0.9998 - val_loss: 4.8966e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 6.2205e-04 - accuracy: 0.9998 - val_loss: 7.0031e-05 - val_accuracy: 1.0000
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.3301e-04 - accuracy: 1.0000 - val_loss: 1.4065e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.1732e-04 - accuracy: 0.9998 - val_loss: 1.2185e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 5.9926e-05 - accuracy: 1.0000 - val_loss: 1.2158e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.3886e-04 - accuracy: 1.0000 - val_loss: 1.3192e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 9.0460e-04 - accuracy: 0.9995 - val_loss: 2.0767e-06 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 5.0271e-04 - accuracy: 0.9998 - val_loss: 0.0211 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.2953e-04 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 6.9947e-05 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.2006e-04 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 2.1135e-04 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 1.4368e-04 - accuracy: 1.0000 - val_loss: 4.4503e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 8.0911e-04 - accuracy: 0.9998 - val_loss: 4.0792e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 35ms/step - loss: 6.9295e-05 - accuracy: 1.0000 - val_loss: 4.0525e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 1.5276e-04 - accuracy: 1.0000 - val_loss: 3.9995e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 36ms/step - loss: 3.5949e-05 - accuracy: 1.0000 - val_loss: 4.1839e-06 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 38ms/step - loss: 2.0254e-04 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0131 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.5450e-04 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 37ms/step - loss: 3.8820e-04 - accuracy: 0.9998 - val_loss: 0.0102 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 37ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0116 - val_accuracy: 0.9975
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 5.9107e-05 - accuracy: 1.0000 - val_loss: 8.5141e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.5008e-05 - accuracy: 1.0000 - val_loss: 7.8824e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.1540e-05 - accuracy: 1.0000 - val_loss: 7.8467e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.2816e-05 - accuracy: 1.0000 - val_loss: 7.7454e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0510e-04 - accuracy: 1.0000 - val_loss: 7.2120e-07 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 2.1708e-05 - accuracy: 1.0000 - val_loss: 5.7699e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.7249e-06 - accuracy: 1.0000 - val_loss: 7.5248e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.8301e-06 - accuracy: 1.0000 - val_loss: 1.2375e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.8412e-05 - accuracy: 1.0000 - val_loss: 8.0158e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.7994e-06 - accuracy: 1.0000 - val_loss: 1.0823e-04 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 7.0253e-06 - accuracy: 1.0000 - val_loss: 5.9779e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.2944e-05 - accuracy: 1.0000 - val_loss: 6.0494e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.9960e-06 - accuracy: 1.0000 - val_loss: 4.9230e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 7.2090e-06 - accuracy: 1.0000 - val_loss: 4.9796e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.7030e-05 - accuracy: 1.0000 - val_loss: 5.6977e-07 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 3.2922e-06 - accuracy: 1.0000 - val_loss: 6.6576e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 5.7559e-06 - accuracy: 1.0000 - val_loss: 6.0795e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 42ms/step - loss: 8.3364e-06 - accuracy: 1.0000 - val_loss: 6.0497e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 2.5869e-05 - accuracy: 1.0000 - val_loss: 6.0556e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 42ms/step - loss: 4.7879e-06 - accuracy: 1.0000 - val_loss: 6.0586e-07 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.1112e-05 - accuracy: 1.0000 - val_loss: 1.7095e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0454e-05 - accuracy: 1.0000 - val_loss: 1.8751e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 41ms/step - loss: 8.4955e-06 - accuracy: 1.0000 - val_loss: 2.0053e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 42ms/step - loss: 1.0260e-05 - accuracy: 1.0000 - val_loss: 2.1095e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 43ms/step - loss: 1.3378e-05 - accuracy: 1.0000 - val_loss: 2.1227e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 135...

# %% [markdown]
# ### Creating Data Set

# %%
bonafide_files = []
spoof_files = []
print('loading bonafide training file names...')
for i in range(training_bonafide_folders + 1):
    bonafide_files.extend(glob.glob(data_loc+'train/bonafide_'+str(i)+'/*.txt'))

print('loading spoof training file names...')
for i in range(training_spoof_folders + 1):
    spoof_files.extend(glob.glob(data_loc+'train/spoof_'+str(i)+'/*.txt'))

print('loading validation bonafide file names...')
for i in range(validation_bonafide_folders + 1):
    bonafide_files.extend(glob.glob(data_loc+'dev/bonafide_'+str(i)+'/*.txt'))

print('loading validation spoof file names...')
for i in range(validation_spoof_folders + 1):
    spoof_files.extend(glob.glob(data_loc+'dev/spoof_'+str(i)+'/*.txt'))
# Out:
# loading bonafide training file names...
# loading spoof training file names...
# loading validation bonafide file names...
# loading validation spoof file names...

# %%
import random
random.shuffle(bonafide_files)
random.shuffle(spoof_files)

bonafide_test_set = bonafide_files[0:500]
spoof_test_set = spoof_files[0:4400]

with open(data_loc + "bonafide_test_set_files.txt", "w") as fp:
    json.dump(bonafide_test_set, fp)

with open(data_loc + "spoof_test_set_files.txt", "w") as fp:
    json.dump(spoof_test_set, fp)

bonafide_valid_set = bonafide_files[500:1000]
spoof_valid_set = spoof_files[4400:8800]

with open(data_loc + "bonafide_valid_set_files.txt", "w") as fp:
    json.dump(bonafide_valid_set, fp)

with open(data_loc + "spoof_valid_set_files.txt", "w") as fp:
    json.dump(spoof_valid_set, fp)

bonafide_train_set = bonafide_files[1000:]
spoof_train_set = spoof_files[8800:]

with open(data_loc + "bonafide_train_set_files.txt", "w") as fp:
    json.dump(bonafide_train_set, fp)

with open(data_loc + "spoof_train_set_files.txt", "w") as fp:
    json.dump(spoof_train_set, fp)

# %% [markdown]
# ### Extracting files to exploit caching

# %%
for i in range(46):
    print("!unzip -o '/content/gdrive/My Drive/MLSP Project/CQCC/train/spoof_{}.zip' -d '/content/gdrive/My Drive/MLSP Project/CQCC/train/'".format(i))
