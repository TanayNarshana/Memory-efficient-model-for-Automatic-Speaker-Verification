# %%
import numpy as np
import librosa
import os
import glob
import gc
import tensorflow as tf
from tensorflow import keras
import json

from google.colab import drive
drive.mount('/content/gdrive')
driveLoc='/content/gdrive/My Drive/MLSP Project/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data_loc = driveLoc + 'CQCC/'

training_bonafide_folders = 6
training_spoof_folders = 46

validation_bonafide_folders = 6
validation_spoof_folders = 45

samples_per_folder = 500

# %% [markdown]
# ### Training Model

# %%
training_samples = 4000
validation_samples = 400
ratio_of_bonafide_samples = 0.5
data_iterations = 10
epochs_per_iteration = 5
size_of_batch = 128
alpha = 0.001 #learning_rate

# %%
training_data_mean = np.loadtxt(data_loc+'train_mean_CQCC.txt', delimiter=',')
training_data_stddev = np.loadtxt(data_loc+'train_stddev_CQCC.txt', delimiter=',')
(dim1, dim2) = np.shape(training_data_mean)
print(dim1, dim2)

def GenerateFeatures(filename): #Generates Normalized Features
    features = np.loadtxt(filename, delimiter=',')
    return (features-training_data_mean)/training_data_stddev
# Out:
# 90 469

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Creating Bonafide Training Data

# %%
with open(data_loc + "bonafide_train_set_files.txt", "r") as fp:
    bonafide_train_files = json.load(fp)

bonafide_train_data = np.zeros((len(bonafide_train_files), dim1, dim2), dtype = np.float32)

for i in range(len(bonafide_train_files)):
    bonafide_train_data[i,:,:] = GenerateFeatures(bonafide_train_files[i])
    if (i+1)%500 == 0:
        print('Generated {} bonafide features...'.format(i+1))

del bonafide_train_files
gc.collect()
# Out:
# Generated 500 bonafide features...
# Generated 1000 bonafide features...
# Generated 1500 bonafide features...
# Generated 2000 bonafide features...
# Generated 2500 bonafide features...
# Generated 3000 bonafide features...
# Generated 3500 bonafide features...
# Generated 4000 bonafide features...
# 0

# %%
with open(data_loc + "spoof_train_set_files.txt", "r") as fp:
    spoof_train_files = json.load(fp)

with open(data_loc + "bonafide_valid_set_files.txt", "r") as fp:
    bonafide_valid_files = json.load(fp)

with open(data_loc + "spoof_valid_set_files.txt", "r") as fp:
    spoof_valid_files = json.load(fp)

# %% [markdown]
# ### Model Creation and Loading

# %%
print(keras.backend.image_data_format())
img_shape = (dim1, dim2, 1)
# Out:
# channels_last

# %%
def CreateModel(dropout_rate, kernel_no):
    model = keras.models.Sequential()
    # initializer = tf.keras.initializers.GlorotUniform()
    opt = keras.optimizers.Adam(learning_rate=alpha)

    # input-processing block
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), input_shape=img_shape, 
                                activation='relu', strides = 2, padding = 'same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2)) # remove thisssssss

    # convolutional-block (1)
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(4, 4), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    # # convolutional-block (2)
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(4, 4), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    # convolutional-block (3)
    # model.add(keras.layers.Conv2D(kernel_no, kernel_size=(2, 2), activation='relu'))
    # model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    # model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    # # convolutional-block (4)
    # model.add(keras.layers.Conv2D(kernel_no, kernel_size=(4, 4), activation='relu'))
    # model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.Conv2D(kernel_no, kernel_size=(3, 3), activation='relu'))
    # model.add(keras.layers.BatchNormalization())
    # model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=2))

    model.add( keras.layers.Flatten() )

    # classification-block
    model.add(keras.layers.Dropout(dropout_rate))
    model.add( keras.layers.Dense(64))
    model.add( keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dropout(dropout_rate))
    model.add( keras.layers.Dense(32))

    # output layer
    model.add( keras.layers.Dense(2, activation='softmax') )

    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model

# %%
model1 = CreateModel(0.1, 4)
model2 = CreateModel(0.15, 4)
model3 = CreateModel(0.2, 4)
model4 = CreateModel(0.25, 4)
model5 = CreateModel(0.3, 4)
model6 = CreateModel(0.1, 8)
model7 = CreateModel(0.15, 8)
model8 = CreateModel(0.2, 8)
model9 = CreateModel(0.25, 8)
model10 = CreateModel(0.3, 8)

# %%
model1 = keras.models.load_model(driveLoc+'Models/20_june01/6')
model2 = keras.models.load_model(driveLoc+'Models/20_june02/6')
model3 = keras.models.load_model(driveLoc+'Models/20_june03/6')
model4 = keras.models.load_model(driveLoc+'Models/20_june04/6')
model5 = keras.models.load_model(driveLoc+'Models/20_june05/6')
model6 = keras.models.load_model(driveLoc+'Models/20_june06/6')
model7 = keras.models.load_model(driveLoc+'Models/20_june07/6')
model8 = keras.models.load_model(driveLoc+'Models/20_june08/6')
model9 = keras.models.load_model(driveLoc+'Models/20_june09/6')
model10 = keras.models.load_model(driveLoc+'Models/20_june10/6')

# keras.backend.set_value(model1.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model2.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model3.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model4.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model5.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model6.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model7.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model8.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model9.optimizer.learning_rate, alpha/2)
# keras.backend.set_value(model10.optimizer.learning_rate, alpha/2)

print(keras.backend.eval(model1.optimizer.lr))
print(keras.backend.eval(model2.optimizer.lr))
print(keras.backend.eval(model3.optimizer.lr))
print(keras.backend.eval(model4.optimizer.lr))
print(keras.backend.eval(model5.optimizer.lr))
print(keras.backend.eval(model6.optimizer.lr))
print(keras.backend.eval(model7.optimizer.lr))
print(keras.backend.eval(model8.optimizer.lr))
print(keras.backend.eval(model9.optimizer.lr))
print(keras.backend.eval(model10.optimizer.lr))
# Out:
# 0.0005
# 0.0005
# 0.0005
# 0.0005
# 0.0005
# 0.0005
# 0.0005
# 0.0005
# 0.0005
# 0.0005

# %%
alpha = keras.backend.eval(model10.optimizer.lr)

keras.backend.set_value(model1.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model2.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model3.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model4.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model5.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model6.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model7.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model8.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model9.optimizer.learning_rate, alpha/2)
keras.backend.set_value(model10.optimizer.learning_rate, alpha/2)

print(keras.backend.eval(model1.optimizer.lr))
print(keras.backend.eval(model2.optimizer.lr))
print(keras.backend.eval(model3.optimizer.lr))
print(keras.backend.eval(model4.optimizer.lr))
print(keras.backend.eval(model5.optimizer.lr))
print(keras.backend.eval(model6.optimizer.lr))
print(keras.backend.eval(model7.optimizer.lr))
print(keras.backend.eval(model8.optimizer.lr))
print(keras.backend.eval(model9.optimizer.lr))
print(keras.backend.eval(model10.optimizer.lr))
# Out:
# 0.00025
# 0.00025
# 0.00025
# 0.00025
# 0.00025
# 0.00025
# 0.00025
# 0.00025
# 0.00025
# 0.00025

# %% [markdown]
# ### Training

# %%
training_data = np.zeros((training_samples, dim1, dim2, 1), dtype = np.float32)
validation_data = np.zeros((validation_samples, dim1, dim2, 1), dtype = np.float32)

training_fill = training_samples//2
validation_fill = validation_samples//2
len_spoof_train_file = len(spoof_train_files)
len_bonafide_valid_file = len(bonafide_valid_files)
len_spoof_valid_file = len(spoof_valid_files)
bon_train_samples = np.shape(bonafide_train_data)[0]
training_bonafide_number = int(ratio_of_bonafide_samples*training_samples)
validation_bonafide_number = int(ratio_of_bonafide_samples*validation_samples)

bonafide_label = 0

j = 0
k = 0

count = 60
i = 0
print('Generating Data for training process no. {}...'.format(count+1))
while  i <  data_iterations*len_spoof_train_file:
    i+=1
    training_data[i%training_fill,:,:,0] = GenerateFeatures(spoof_train_files[i%len_spoof_train_file])
    if (i+1)%training_fill == 0:
        print("Last data point was generated with index {}".format(i))
        for p in range(training_fill):
            training_data[p+training_fill,:,:,0] = bonafide_train_data[(j+p)%bon_train_samples, :, :]
        j += training_fill

        training_labels = np.append((1-bonafide_label)*np.ones(training_samples-training_bonafide_number), 
                                        bonafide_label*np.ones(training_bonafide_number))
                                        
        validation_labels = np.append(bonafide_label*np.ones(validation_bonafide_number), 
                                        (1-bonafide_label)*np.ones(validation_samples-validation_bonafide_number))
        for p in range(validation_fill):
            validation_data[p,:,:,0] = GenerateFeatures(bonafide_valid_files[k%len_bonafide_valid_file])
            validation_data[p+validation_fill,:,:,0] = GenerateFeatures(spoof_valid_files[k%len_spoof_valid_file])
            k += 1
        
        print("Training Model 01...")
        model1.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 02...")
        model2.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 03...")
        model3.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 04...")
        model4.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 05...")
        model5.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 06...")
        model6.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 07...")
        model7.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 08...")
        model8.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 09...")
        model9.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        print("Training Model 10...")
        model10.fit(x = training_data, y = training_labels, batch_size = size_of_batch, epochs = epochs_per_iteration,
              validation_data = (validation_data, validation_labels), shuffle = True)
        
        if (count+1)%10 == 0:
            model1.save(driveLoc+'Models/20_june01/'+str((count+1)//10))
            model2.save(driveLoc+'Models/20_june02/'+str((count+1)//10))
            model3.save(driveLoc+'Models/20_june03/'+str((count+1)//10))
            model4.save(driveLoc+'Models/20_june04/'+str((count+1)//10))
            model5.save(driveLoc+'Models/20_june05/'+str((count+1)//10))
            model6.save(driveLoc+'Models/20_june06/'+str((count+1)//10))
            model7.save(driveLoc+'Models/20_june07/'+str((count+1)//10))
            model8.save(driveLoc+'Models/20_june08/'+str((count+1)//10))
            model9.save(driveLoc+'Models/20_june09/'+str((count+1)//10))
            model10.save(driveLoc+'Models/20_june10/'+str((count+1)//10))
        if count > 20 and (count+1)%20 == 0:
            alpha = keras.backend.eval(model1.optimizer.lr)
            print('Updating step size to {}...'.format(alpha/2))
            keras.backend.set_value(model1.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model2.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model3.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model4.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model5.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model6.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model7.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model8.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model9.optimizer.learning_rate, alpha/2)
            keras.backend.set_value(model10.optimizer.learning_rate, alpha/2)
        if(count+1 == 40):
            epochs_per_iteration = 5
        count+=1    
        print('Generating Data for training process no. {}...'.format(count+1))
        
        del training_labels
        del validation_labels
        gc.collect()
# Out:
# Generating Data for training process no. 61...
# Last data point was generated with index 1999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 17s 29ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0140 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 3.9979e-04 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 8.4378e-04 - accuracy: 0.9998 - val_loss: 0.0135 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0072 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 5.6002e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 2s 26ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0089 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0077 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0048 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0102 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0163 - val_accuracy: 0.9950
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 2s 26ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0172 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0033 - accuracy: 0.9980 - val_loss: 0.0083 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0122 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0057 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 9.0793e-04 - val_accuracy: 1.0000
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 2s 27ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 2.4965e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 8.4448e-04 - accuracy: 0.9998 - val_loss: 2.2451e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 1.0356e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 6.5276e-04 - accuracy: 1.0000 - val_loss: 5.0756e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 1.0220e-05 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 2s 26ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 6.2521e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0014 - val_accuracy: 1.0000
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 2s 30ms/step - loss: 2.4822e-04 - accuracy: 0.9998 - val_loss: 0.0385 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 5.6999e-04 - accuracy: 0.9995 - val_loss: 0.0029 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.2361e-05 - accuracy: 1.0000 - val_loss: 4.3174e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.1005e-05 - accuracy: 1.0000 - val_loss: 8.2069e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.2374e-05 - accuracy: 1.0000 - val_loss: 2.9200e-05 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 2s 28ms/step - loss: 7.3053e-05 - accuracy: 1.0000 - val_loss: 6.4566e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 3.5115e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.0743e-04 - accuracy: 1.0000 - val_loss: 2.1073e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 2.8458e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.4654e-05 - accuracy: 1.0000 - val_loss: 1.1011e-06 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 2s 28ms/step - loss: 2.7987e-04 - accuracy: 1.0000 - val_loss: 8.2606e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 4.7797e-04 - accuracy: 0.9998 - val_loss: 2.4297e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.2422e-05 - accuracy: 1.0000 - val_loss: 9.0387e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.6667e-04 - accuracy: 1.0000 - val_loss: 5.7281e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.8033e-04 - accuracy: 0.9998 - val_loss: 5.5175e-06 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 2s 28ms/step - loss: 4.1413e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.7074e-04 - accuracy: 1.0000 - val_loss: 3.0166e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.2101e-04 - accuracy: 1.0000 - val_loss: 1.6723e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.9609e-05 - accuracy: 1.0000 - val_loss: 5.1101e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.2092e-04 - accuracy: 1.0000 - val_loss: 5.4356e-05 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 2s 28ms/step - loss: 1.7834e-04 - accuracy: 1.0000 - val_loss: 9.7012e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.9798e-04 - accuracy: 1.0000 - val_loss: 3.0445e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.0679e-05 - accuracy: 1.0000 - val_loss: 1.3691e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.2866e-04 - accuracy: 1.0000 - val_loss: 5.7905e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 5.8716e-04 - accuracy: 0.9995 - val_loss: 3.0288e-04 - val_accuracy: 1.0000
# Generating Data for training process no. 62...
# Last data point was generated with index 3999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0076 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0081 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0086 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.5466e-04 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0018 - accuracy: 0.9987 - val_loss: 0.0093 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0026 - accuracy: 0.9985 - val_loss: 0.0292 - val_accuracy: 0.9875
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 8.8978e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0396 - val_accuracy: 0.9900
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1500 - val_accuracy: 0.9675
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0085 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.0488e-04 - accuracy: 0.9995 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0144 - val_accuracy: 0.9925
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 6.9098e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 8.6826e-04 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.8647e-04 - accuracy: 0.9995 - val_loss: 0.0041 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.3784e-04 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0059 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9987 - val_loss: 0.0070 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0083 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0113 - val_accuracy: 0.9975
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.4191e-05 - accuracy: 1.0000 - val_loss: 7.6495e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.0467e-06 - accuracy: 1.0000 - val_loss: 5.3828e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.3020e-05 - accuracy: 1.0000 - val_loss: 4.8324e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.9644e-05 - accuracy: 1.0000 - val_loss: 3.0617e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 9.5938e-04 - accuracy: 0.9995 - val_loss: 0.0328 - val_accuracy: 0.9900
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 5.9603e-04 - accuracy: 0.9995 - val_loss: 7.6843e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.3626e-05 - accuracy: 1.0000 - val_loss: 2.0970e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.6919e-05 - accuracy: 1.0000 - val_loss: 2.5794e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.0977e-05 - accuracy: 1.0000 - val_loss: 3.2694e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.3537e-05 - accuracy: 1.0000 - val_loss: 3.8046e-06 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.8724e-04 - accuracy: 1.0000 - val_loss: 3.4869e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 6.4386e-04 - accuracy: 0.9998 - val_loss: 4.3624e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.9269e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 1.0584e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.7296e-04 - accuracy: 1.0000 - val_loss: 5.0609e-05 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.3585e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 5.2873e-05 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0129e-04 - accuracy: 1.0000 - val_loss: 2.0573e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0244e-04 - accuracy: 1.0000 - val_loss: 2.5829e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.3843e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 1.2732e-04 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 5.5466e-05 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.0490e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.8956e-06 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.6793e-04 - accuracy: 0.9998 - val_loss: 1.2358e-04 - val_accuracy: 1.0000
# Generating Data for training process no. 63...
# Last data point was generated with index 5999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 7.2150e-04 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0532 - val_accuracy: 0.9900
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0514 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 5.7264e-04 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9900
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 3.1504e-04 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9900
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0092 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.3921e-04 - accuracy: 0.9998 - val_loss: 5.4822e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0182 - val_accuracy: 0.9950
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0228 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0186 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0170 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0160 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0162 - val_accuracy: 0.9950
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0455 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0133 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 5.1609e-04 - accuracy: 0.9998 - val_loss: 0.0087 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.4967e-04 - accuracy: 0.9995 - val_loss: 0.0565 - val_accuracy: 0.9900
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 4.6947e-04 - accuracy: 0.9998 - val_loss: 0.0136 - val_accuracy: 0.9950
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0280 - val_accuracy: 0.9925
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0420 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 4.0991e-04 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9925
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9925
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 5.6469e-06 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 9.9019e-05 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.5472e-05 - accuracy: 1.0000 - val_loss: 0.0286 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.3733e-04 - accuracy: 0.9998 - val_loss: 0.0680 - val_accuracy: 0.9725
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.4621e-05 - accuracy: 1.0000 - val_loss: 0.0279 - val_accuracy: 0.9975
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 5.8974e-05 - accuracy: 1.0000 - val_loss: 7.2099e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.6194e-04 - accuracy: 0.9998 - val_loss: 5.2215e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.5248e-05 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.0032e-04 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.4631e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9975
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.6609e-05 - accuracy: 1.0000 - val_loss: 0.0108 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.7055e-04 - accuracy: 0.9998 - val_loss: 0.0163 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.3943e-05 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.0102e-05 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.5412e-05 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9950
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.2817e-05 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.3684e-05 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.8048e-05 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0040 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.7258e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9975
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 6.0929e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.0113 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.7183e-05 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.7260e-04 - accuracy: 0.9998 - val_loss: 0.0143 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.3596e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9975
# Generating Data for training process no. 64...
# Last data point was generated with index 7999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 1.5491e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 2.1476e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 9.3451e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 7.2714e-05 - val_accuracy: 1.0000
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 4.1647e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0237 - val_accuracy: 0.9900
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.5036 - val_accuracy: 0.8650
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 6.6304e-04 - accuracy: 0.9998 - val_loss: 0.0216 - val_accuracy: 0.9900
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 3.7494e-04 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9850
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0033 - accuracy: 0.9985 - val_loss: 5.7367e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.3328e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 2.0292e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 3.6198e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 0.0012 - val_accuracy: 1.0000
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 8.7759e-04 - accuracy: 0.9998 - val_loss: 7.6287e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 4.8098e-04 - accuracy: 1.0000 - val_loss: 6.1627e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 1.4157e-04 - accuracy: 1.0000 - val_loss: 1.0631e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 20ms/step - loss: 5.6886e-04 - accuracy: 1.0000 - val_loss: 1.4258e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 3.0180e-04 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 6.1501e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.2614e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0027 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 1.6953e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 6.8005e-04 - val_accuracy: 1.0000
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.4864e-05 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 9.3984e-04 - accuracy: 0.9998 - val_loss: 2.8736e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.2147e-04 - accuracy: 0.9998 - val_loss: 5.7219e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1391e-04 - accuracy: 1.0000 - val_loss: 3.5631e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.1536e-05 - accuracy: 1.0000 - val_loss: 6.5270e-05 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.5333e-04 - accuracy: 0.9998 - val_loss: 2.0405e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.8447e-04 - accuracy: 1.0000 - val_loss: 8.3624e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.7813e-05 - accuracy: 1.0000 - val_loss: 5.4022e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 9.9449e-04 - accuracy: 0.9998 - val_loss: 1.4618e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 6.4318e-05 - accuracy: 1.0000 - val_loss: 3.2780e-05 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.9819e-05 - accuracy: 1.0000 - val_loss: 4.4672e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.6469e-05 - accuracy: 1.0000 - val_loss: 4.1901e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.1373e-05 - accuracy: 1.0000 - val_loss: 3.9636e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.4285e-05 - accuracy: 1.0000 - val_loss: 3.8950e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.7820e-05 - accuracy: 1.0000 - val_loss: 3.7788e-07 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.4931e-05 - accuracy: 1.0000 - val_loss: 3.0077e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.4026e-05 - accuracy: 1.0000 - val_loss: 2.5120e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.2997e-05 - accuracy: 1.0000 - val_loss: 8.5495e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 9.9465e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0069 - val_accuracy: 0.9975
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 5.3105e-04 - accuracy: 0.9995 - val_loss: 8.1588e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.2946e-05 - accuracy: 1.0000 - val_loss: 1.1851e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.8512e-04 - accuracy: 0.9998 - val_loss: 5.7816e-08 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 3.4212e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 5.8752e-04 - accuracy: 0.9995 - val_loss: 6.9243e-06 - val_accuracy: 1.0000
# Generating Data for training process no. 65...
# Last data point was generated with index 9999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0512 - val_accuracy: 0.9850
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 7.1815e-04 - accuracy: 0.9998 - val_loss: 0.0110 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 3.7714e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0025 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.0184 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0057 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0132 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0113 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0024 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0063 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 6.2658e-04 - accuracy: 0.9998 - val_loss: 0.0091 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.0120 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0312 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0250 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.9992 - val_loss: 0.0335 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0073 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 6.8646e-04 - accuracy: 0.9998 - val_loss: 0.0038 - val_accuracy: 0.9975
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0161 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0093 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0088 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0110 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0140 - val_accuracy: 0.9975
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.8815e-05 - accuracy: 1.0000 - val_loss: 8.1366e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.3701e-04 - accuracy: 0.9998 - val_loss: 0.0693 - val_accuracy: 0.9850
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.6286e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.3514e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.3088e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.3748e-05 - accuracy: 1.0000 - val_loss: 4.6523e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.2010e-05 - accuracy: 1.0000 - val_loss: 1.8991e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.7607e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0951e-05 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.8676e-05 - accuracy: 1.0000 - val_loss: 6.7219e-04 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.0607e-05 - accuracy: 1.0000 - val_loss: 1.2484e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.1524e-05 - accuracy: 1.0000 - val_loss: 1.6140e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 5.2116e-06 - accuracy: 1.0000 - val_loss: 1.8622e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.2695e-05 - accuracy: 1.0000 - val_loss: 1.8416e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.4620e-04 - accuracy: 0.9998 - val_loss: 6.2523e-04 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.2590e-05 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9900
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 9.6626e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.3409e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.5490e-05 - accuracy: 1.0000 - val_loss: 8.2158e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.8664e-05 - accuracy: 1.0000 - val_loss: 2.4084e-04 - val_accuracy: 1.0000
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 6.0434e-05 - accuracy: 1.0000 - val_loss: 1.1360e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1377e-04 - accuracy: 1.0000 - val_loss: 7.7467e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.8097e-06 - accuracy: 1.0000 - val_loss: 9.9156e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.8864e-04 - accuracy: 0.9998 - val_loss: 2.6556e-05 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.1316e-05 - accuracy: 1.0000 - val_loss: 4.3145e-05 - val_accuracy: 1.0000
# Generating Data for training process no. 66...
# Last data point was generated with index 11999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0274 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0139 - val_accuracy: 0.9900
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0116 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0074 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0131 - val_accuracy: 0.9950
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0133 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0504 - val_accuracy: 0.9800
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0384 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0076 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.0104 - val_accuracy: 0.9975
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0088 - accuracy: 0.9980 - val_loss: 0.0177 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0436 - val_accuracy: 0.9925
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0111 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0046 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0088 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 7.7982e-05 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.0290 - val_accuracy: 0.9875
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 8.2056e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 6.6579e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0044 - val_accuracy: 0.9975
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.0211 - val_accuracy: 0.9925
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0226 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0254 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0099 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 20ms/step - loss: 0.0030 - accuracy: 0.9985 - val_loss: 0.0039 - val_accuracy: 1.0000
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 9.2604e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.5363e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.1895e-04 - accuracy: 0.9998 - val_loss: 0.0516 - val_accuracy: 0.9875
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.1516e-04 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9850
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.8537e-04 - accuracy: 0.9998 - val_loss: 0.0665 - val_accuracy: 0.9875
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 3.2258e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.6047e-05 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.7309e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.8024e-04 - accuracy: 1.0000 - val_loss: 7.1209e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.0500e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 9.5160e-04 - accuracy: 0.9992 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1440e-04 - accuracy: 1.0000 - val_loss: 4.3804e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.4883e-04 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0151e-04 - accuracy: 1.0000 - val_loss: 4.1832e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 6.1034e-04 - accuracy: 0.9998 - val_loss: 0.0013 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 4.6232e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.8465e-04 - accuracy: 0.9995 - val_loss: 0.0196 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 1.9499e-04 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.4085e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.4825e-05 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9950
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.4764e-04 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.8942e-04 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.3359e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.5800e-05 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.6576e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9975
# Generating Data for training process no. 67...
# Last data point was generated with index 13999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0195 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0110 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 8.3478e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0108 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.0087 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0115 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0033 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.8558 - val_accuracy: 0.8575
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0032 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 6.6830e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0060 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 2.2908e-04 - val_accuracy: 1.0000
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 9.1939e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0167 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 5.1315e-04 - accuracy: 0.9998 - val_loss: 0.0046 - val_accuracy: 0.9975
# Training Model 05...
# Epoch 1/5
# ...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0213 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0345 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.0226 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.7919e-04 - accuracy: 0.9995 - val_loss: 0.0198 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 2.3969e-04 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9975
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0741 - val_accuracy: 0.9600
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0080 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0028 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.8831e-04 - accuracy: 0.9995 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 6.3485e-04 - accuracy: 0.9998 - val_loss: 0.0022 - val_accuracy: 1.0000
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0079 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 5.7136e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0085 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.0086 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0087 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.2464e-04 - accuracy: 0.9998 - val_loss: 6.3288e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.6493e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.3011e-04 - accuracy: 0.9998 - val_loss: 1.5344e-05 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 4.1740e-04 - accuracy: 1.0000 - val_loss: 3.1281e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 9.5450e-04 - val_accuracy: 1.0000
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0072 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0028 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0035 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0067 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0044 - val_accuracy: 0.9975
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 3.4474e-04 - accuracy: 0.9998 - val_loss: 1.9282e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.4527e-05 - accuracy: 1.0000 - val_loss: 2.0921e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.5290e-06 - accuracy: 1.0000 - val_loss: 2.8937e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1299e-04 - accuracy: 1.0000 - val_loss: 1.3292e-07 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 3.5324e-05 - accuracy: 1.0000 - val_loss: 1.4543e-07 - val_accuracy: 1.0000
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 8.3442e-06 - accuracy: 1.0000 - val_loss: 1.2843e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.6344e-05 - accuracy: 1.0000 - val_loss: 1.2718e-06 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1790e-05 - accuracy: 1.0000 - val_loss: 1.4708e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1895e-05 - accuracy: 1.0000 - val_loss: 1.7174e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.7766e-06 - accuracy: 1.0000 - val_loss: 1.7442e-06 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 1.2996e-04 - accuracy: 1.0000 - val_loss: 3.2306e-06 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.7590e-05 - accuracy: 1.0000 - val_loss: 1.8593e-05 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.6429e-04 - accuracy: 1.0000 - val_loss: 2.7778e-06 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 2.4510e-05 - accuracy: 1.0000 - val_loss: 2.7257e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 4.5395e-06 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 7.8254e-04 - accuracy: 0.9998 - val_loss: 0.0102 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 24ms/step - loss: 1.1271e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.0662e-05 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.7872e-04 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.4358e-06 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9975
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 25ms/step - loss: 4.4348e-05 - accuracy: 1.0000 - val_loss: 9.9036e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.2084e-06 - accuracy: 1.0000 - val_loss: 9.1955e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 5.4947e-06 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.3702e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.9399e-05 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 0.9975
# Generating Data for training process no. 100...
# Last data point was generated with index 79999
# Training Model 01...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0066 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.0069 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.3045e-04 - accuracy: 0.9998 - val_loss: 0.0067 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0060 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.4693e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9950
# Training Model 02...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.6537e-04 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0175 - val_accuracy: 0.9925
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0175 - val_accuracy: 0.9925
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 0.0181 - val_accuracy: 0.9925
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 6.8352e-04 - accuracy: 0.9998 - val_loss: 0.0177 - val_accuracy: 0.9925
# Training Model 03...
# Epoch 1/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.5737e-04 - accuracy: 0.9998 - val_loss: 0.0173 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 3.2904e-04 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 8.2585e-04 - accuracy: 0.9998 - val_loss: 0.0245 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 7.4322e-04 - accuracy: 0.9998 - val_loss: 0.0238 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 6.4445e-04 - accuracy: 0.9998 - val_loss: 0.0288 - val_accuracy: 0.9975
# Training Model 04...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.3644e-04 - accuracy: 0.9998 - val_loss: 0.0073 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 4.2279e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9950
# Epoch 4/5
# 32/32 [==============================] - 1s 21ms/step - loss: 9.2517e-04 - accuracy: 0.9998 - val_loss: 0.0045 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 22ms/step - loss: 3.8638e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9950
# Training Model 05...
# Epoch 1/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.7512e-04 - accuracy: 0.9998 - val_loss: 0.0134 - val_accuracy: 0.9950
# Epoch 2/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.0110 - val_accuracy: 0.9950
# Epoch 3/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0133 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 22ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0097 - val_accuracy: 0.9950
# Epoch 5/5
# 32/32 [==============================] - 1s 21ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0135 - val_accuracy: 0.9950
# Training Model 06...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 6.9044e-05 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0352e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 24ms/step - loss: 4.6674e-06 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.1397e-06 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.4237e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9975
# Training Model 07...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 9.4023e-06 - accuracy: 1.0000 - val_loss: 7.2267e-07 - val_accuracy: 1.0000
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.2166e-05 - accuracy: 1.0000 - val_loss: 8.4038e-07 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.4886e-06 - accuracy: 1.0000 - val_loss: 7.9687e-07 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 24ms/step - loss: 1.3222e-04 - accuracy: 1.0000 - val_loss: 1.2581e-06 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 7.8837e-05 - accuracy: 1.0000 - val_loss: 1.0338e-06 - val_accuracy: 1.0000
# Training Model 08...
# Epoch 1/5
# 32/32 [==============================] - 1s 25ms/step - loss: 3.6792e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 23ms/step - loss: 9.3763e-05 - accuracy: 1.0000 - val_loss: 9.2974e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.8387e-05 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 6.5798e-05 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 5.4659e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Training Model 09...
# Epoch 1/5
# 32/32 [==============================] - 1s 25ms/step - loss: 1.0797e-05 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 24ms/step - loss: 6.8791e-06 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 24ms/step - loss: 1.1674e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 8.8154e-06 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 4.6009e-05 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9975
# Training Model 10...
# Epoch 1/5
# 32/32 [==============================] - 1s 24ms/step - loss: 5.7291e-06 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9975
# Epoch 2/5
# 32/32 [==============================] - 1s 24ms/step - loss: 5.0769e-06 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9975
# Epoch 3/5
# 32/32 [==============================] - 1s 24ms/step - loss: 6.6342e-06 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9975
# Epoch 4/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0590e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9975
# Epoch 5/5
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1200e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9975
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june01/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june02/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june03/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june04/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june05/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june06/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june07/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june08/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june09/10/assets
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/MLSP Project/Models/20_june10/10/assets
# Updating step size to 6.25000029685907e-05...
# Generating Data for training process no. 101...

# %% [markdown]
# ### Creating Data Set

# %%
bonafide_files = []
spoof_files = []
print('loading bonafide training file names...')
for i in range(training_bonafide_folders + 1):
    bonafide_files.extend(glob.glob(data_loc+'train/bonafide_'+str(i)+'/*.txt'))

print('loading spoof training file names...')
for i in range(training_spoof_folders + 1):
    spoof_files.extend(glob.glob(data_loc+'train/spoof_'+str(i)+'/*.txt'))

print('loading validation bonafide file names...')
for i in range(validation_bonafide_folders + 1):
    bonafide_files.extend(glob.glob(data_loc+'dev/bonafide_'+str(i)+'/*.txt'))

print('loading validation spoof file names...')
for i in range(validation_spoof_folders + 1):
    spoof_files.extend(glob.glob(data_loc+'dev/spoof_'+str(i)+'/*.txt'))
# Out:
# loading bonafide training file names...
# loading spoof training file names...
# loading validation bonafide file names...
# loading validation spoof file names...

# %%
import random
random.shuffle(bonafide_files)
random.shuffle(spoof_files)

bonafide_test_set = bonafide_files[0:500]
spoof_test_set = spoof_files[0:4400]

with open(data_loc + "bonafide_test_set_files.txt", "w") as fp:
    json.dump(bonafide_test_set, fp)

with open(data_loc + "spoof_test_set_files.txt", "w") as fp:
    json.dump(spoof_test_set, fp)

bonafide_valid_set = bonafide_files[500:1000]
spoof_valid_set = spoof_files[4400:8800]

with open(data_loc + "bonafide_valid_set_files.txt", "w") as fp:
    json.dump(bonafide_valid_set, fp)

with open(data_loc + "spoof_valid_set_files.txt", "w") as fp:
    json.dump(spoof_valid_set, fp)

bonafide_train_set = bonafide_files[1000:]
spoof_train_set = spoof_files[8800:]

with open(data_loc + "bonafide_train_set_files.txt", "w") as fp:
    json.dump(bonafide_train_set, fp)

with open(data_loc + "spoof_train_set_files.txt", "w") as fp:
    json.dump(spoof_train_set, fp)

# %% [markdown]
# ### Extracting files to exploit caching

# %%
for i in range(45):
    print("!unzip -o '/content/gdrive/My Drive/MLSP Project/CQCC/dev/spoof_{}.zip' -d '/content/gdrive/My Drive/MLSP Project/CQCC/dev/'".format(i))

# %%
for i in range(6):
    print("print(len(glob.glob('/content/gdrive/My Drive/MLSP Project/CQCC/dev/bonafide_{}/*.txt')))".format(i))
